# %%
import pandas as pd

# %%
mvps = pd.read_csv("mvps.csv")

# %%
mvps
# Out:
#      Unnamed: 0 Rank           Player  Age   Tm  First  Pts Won  Pts Max  \
# 0             0    1   Michael Jordan   27  CHI   77.0    891.0      960
# 1             1    2    Magic Johnson   31  LAL   10.0    497.0      960
# 2             2    3   David Robinson   25  SAS    6.0    476.0      960
# 3             3    4  Charles Barkley   27  PHI    2.0    222.0      960
# 4             4    5      Karl Malone   27  UTA    0.0    142.0      960
# ..          ...  ...              ...  ...  ...    ...      ...      ...
# 481           7    8    Stephen Curry   33  GSW    0.0      4.0     1000
# 482           8    9       Chris Paul   36  PHO    0.0      2.0     1000
# 483           9  10T    DeMar DeRozan   32  CHI    0.0      1.0     1000
# 484          10  10T     Kevin Durant   33  BRK    0.0      1.0     1000
# 485          11  10T     LeBron James   37  LAL    0.0      1.0     1000
#
#      Share   G  ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  \
# 0    0.928  82  ...   6.0   5.5  2.7  1.0  0.539  0.312  0.851  20.3  0.321
# 1    0.518  79  ...   7.0  12.5  1.3  0.2  0.477  0.320  0.906  15.4  0.251
# 2    0.496  82  ...  13.0   2.5  1.5  3.9  0.552  0.143  0.762  17.0  0.264
# 3    0.231  67  ...  10.1   4.2  1.6  0.5  0.570  0.284  0.722  13.4  0.258
# 4    0.148  82  ...  11.8   3.3  1.1  1.0  0.527  0.286  0.770  15.5  0.225
# ..     ...  ..  ...   ...   ...  ...  ...    ...    ...    ...   ...    ...
# 481  0.004  64  ...   5.2   6.3  1.3  0.4  0.437  0.380  0.923   8.0  0.173
# 482  0.002  65  ...   4.4  10.8  1.9  0.3  0.493  0.317  0.837   9.4  0.210
# 483  0.001  76  ...   5.2   4.9  0.9  0.3  0.504  0.352  0.877   8.8  0.154
# 484  0.001  55  ...   7.4   6.4  0.9  0.9  0.518  0.383  0.910   8.4  0.198
# 485  0.001  56  ...   8.2   6.2  1.3  1.1  0.524  0.359  0.756   7.5  0.172
#
#      Year
# 0    1991
# 1    1991
# 2    1991
# 3    1991
# 4    1991
# ..    ...
# 481  2022
# 482  2022
# 483  2022
# 484  2022
# 485  2022
#
# [486 rows x 22 columns]

# %%
mvps = mvps[["Player", "Year", "Pts Won", "Pts Max", "Share"]]

# %%
mvps.head()
# Out:
#             Player  Year  Pts Won  Pts Max  Share
# 0   Michael Jordan  1991    891.0      960  0.928
# 1    Magic Johnson  1991    497.0      960  0.518
# 2   David Robinson  1991    476.0      960  0.496
# 3  Charles Barkley  1991    222.0      960  0.231
# 4      Karl Malone  1991    142.0      960  0.148

# %%
players = pd.read_csv("players.csv")

# %%
players
# Out:
#        Unnamed: 0   Rk              Player Pos Age   Tm   G  GS    MP   FG  \
# 0               0    1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3
# 1               1    2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2
# 2               2    3          Mark Acres   C  28  ORL  68   0  19.3  1.6
# 3               3    4       Michael Adams  PG  28  DEN  66  66  35.5  8.5
# 4               4    5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4
# ...           ...  ...                 ...  ..  ..  ...  ..  ..   ...  ...
# 18880         836  601      Thaddeus Young  PF  33  TOR  26   0  18.3  2.6
# 18881         837  602          Trae Young  PG  23  ATL  76  76  34.9  9.4
# 18882         838  603      Omer Yurtseven   C  23  MIA  56  12  12.6  2.3
# 18883         839  604         Cody Zeller   C  29  POR  27   0  13.1  1.9
# 18884         840  605         Ivica Zubac   C  24  LAC  76  76  24.4  4.1
#
#        ...  ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0      ...  0.6  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1      ...  0.5  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2      ...  2.1  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3      ...  0.9  3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4      ...  1.7  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
# ...    ...  ...  ...  ...   ...  ...  ...  ...  ...   ...   ...
# 18880  ...  1.5  2.9  4.4   1.7  1.2  0.4  0.8  1.7   6.3  2022
# 18881  ...  0.7  3.1  3.7   9.7  0.9  0.1  4.0  1.7  28.4  2022
# 18882  ...  1.5  3.7  5.3   0.9  0.3  0.4  0.7  1.5   5.3  2022
# 18883  ...  1.9  2.8  4.6   0.8  0.3  0.2  0.7  2.1   5.2  2022
# 18884  ...  2.9  5.6  8.5   1.6  0.5  1.0  1.5  2.7  10.3  2022
#
# [18885 rows x 32 columns]

# %%
del players["Unnamed: 0"]
del players["Rk"]

# %%
players
# Out:
#                    Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  \
# 0          Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  .474  ...
# 1      Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  .413  ...
# 2              Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  .509  ...
# 3           Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  .394  ...
# 4            Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  .462  ...
# ...                   ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...
# 18880      Thaddeus Young  PF  33  TOR  26   0  18.3  2.6   5.5  .465  ...
# 18881          Trae Young  PG  23  ATL  76  76  34.9  9.4  20.3  .460  ...
# 18882      Omer Yurtseven   C  23  MIA  56  12  12.6  2.3   4.4  .526  ...
# 18883         Cody Zeller   C  29  POR  27   0  13.1  1.9   3.3  .567  ...
# 18884         Ivica Zubac   C  24  LAC  76  76  24.4  4.1   6.5  .626  ...
#
#        ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0      0.6  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1      0.5  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2      2.1  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3      0.9  3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4      1.7  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
# ...    ...  ...  ...   ...  ...  ...  ...  ...   ...   ...
# 18880  1.5  2.9  4.4   1.7  1.2  0.4  0.8  1.7   6.3  2022
# 18881  0.7  3.1  3.7   9.7  0.9  0.1  4.0  1.7  28.4  2022
# 18882  1.5  3.7  5.3   0.9  0.3  0.4  0.7  1.5   5.3  2022
# 18883  1.9  2.8  4.6   0.8  0.3  0.2  0.7  2.1   5.2  2022
# 18884  2.9  5.6  8.5   1.6  0.5  1.0  1.5  2.7  10.3  2022
#
# [18885 rows x 30 columns]

# %%
players["Player"].head(50)
# Out:
# 0         Alaa Abdelnaby
# 1     Mahmoud Abdul-Rauf
# 2             Mark Acres
# 3          Michael Adams
# 4           Mark Aguirre
# 5            Danny Ainge
# 6            Mark Alarie
# 7           Steve Alford
# 8          Greg Anderson
# 9          Greg Anderson
# 10         Greg Anderson
# 11         Greg Anderson
# 12         Nick Anderson
# 13          Ron Anderson
# 14       Willie Anderson
# 15        Michael Ansley
# 16        B.J. Armstrong
# 17         Vincent Askew
# 18          Keith Askins
# 19           Miloš Babić
# 20          Thurl Bailey
# 21           Cedric Ball
# 22         Ken Bannister
# 23      Charles Barkley*
# 24           Dana Barros
# 25           John Battle
# 26          Kenny Battle
# 27          Kenny Battle
# 28          Kenny Battle
# 29       William Bedford
# 30       Benoit Benjamin
# 31       Benoit Benjamin
# 32       Benoit Benjamin
# 33       Winston Bennett
# 34           Larry Bird*
# 35      Rolando Blackman
# 36          Lance Blanks
# 37       Mookie Blaylock
# 38         Muggsy Bogues
# 39            Manute Bol
# 40        Anthony Bonner
# 41             Sam Bowie
# 42          Randy Breuer
# 43      Frank Brickowski
# 44          Scott Brooks
# 45          Chucky Brown
# 46             Dee Brown
# 47                Player
# 48            Mike Brown
# 49            Tony Brown
# Name: Player, dtype: object

# %%
players["Player"] = players["Player"].str.replace("*","", regex=False)

# %%
players.head(50)
# Out:
#                 Player    Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0       Alaa Abdelnaby     PF   22  POR  43   0   6.7  1.3   2.7   .474  ...
# 1   Mahmoud Abdul-Rauf     PG   21  DEN  67  19  22.5  6.2  15.1   .413  ...
# 2           Mark Acres      C   28  ORL  68   0  19.3  1.6   3.1   .509  ...
# 3        Michael Adams     PG   28  DEN  66  66  35.5  8.5  21.5   .394  ...
# 4         Mark Aguirre     SF   31  DET  78  13  25.7  5.4  11.7   .462  ...
# 5          Danny Ainge     SG   31  POR  80   0  21.4  4.2   8.9   .472  ...
# 6          Mark Alarie     PF   27  WSB  42   1  14.0  2.4   5.4   .440  ...
# 7         Steve Alford     PG   26  DAL  34   0   6.9  1.7   3.4   .504  ...
# 8        Greg Anderson     PF   26  TOT  68   2  13.6  1.7   4.0   .430  ...
# 9        Greg Anderson     PF   26  MIL  26   0   9.5  1.0   2.8   .370  ...
# 10       Greg Anderson     PF   26  NJN   1   0  18.0  4.0   4.0  1.000  ...
# 11       Greg Anderson     PF   26  DEN  41   2  16.1  2.1   4.7   .440  ...
# 12       Nick Anderson     SG   23  ORL  70  42  28.2  5.7  12.2   .467  ...
# 13        Ron Anderson     SF   32  PHI  82  13  28.5  6.2  12.9   .485  ...
# 14     Willie Anderson     SG   24  SAS  75  75  34.6  6.0  13.2   .457  ...
# 15      Michael Ansley     SF   23  ORL  67   1  13.1  2.1   3.9   .548  ...
# 16      B.J. Armstrong     PG   23  CHI  82   0  21.1  3.7   7.7   .481  ...
# 17       Vincent Askew     SG   24  GSW   7   0  12.1  1.7   3.6   .480  ...
# 18        Keith Askins     SF   23  MIA  39   1   6.8  0.9   2.1   .420  ...
# 19         Miloš Babić     PF   22  CLE  12   0   4.3  0.5   1.6   .316  ...
# 20        Thurl Bailey     PF   29  UTA  82  22  30.3  4.9  10.6   .458  ...
# 21         Cedric Ball     PF   22  LAC   7   0   3.7  0.4   1.1   .375  ...
# 22       Ken Bannister     PF   30  LAC  47   3   7.2  0.9   1.7   .531  ...
# 23    Charles Barkley*     SF   27  PHI  67  67  37.3  9.9  17.4   .570  ...
# 24         Dana Barros     PG   23  SEA  66   0  11.4  2.3   4.7   .495  ...
# 25         John Battle     SG   28  ATL  79   2  23.6  5.0  10.9   .461  ...
# 26        Kenny Battle     SG   26  TOT  56   8  16.9  2.4   5.0   .472  ...
# 27        Kenny Battle     SG   26  PHO  16   4  16.4  2.4   5.4   .442  ...
# 28        Kenny Battle     SG   26  DEN  40   4  17.1  2.4   4.9   .485  ...
# 29     William Bedford      C   27  DET  60   4   9.4  1.8   4.0   .438  ...
# 30     Benoit Benjamin      C   26  TOT  70  65  31.9  5.5  11.1   .496  ...
# 31     Benoit Benjamin      C   26  LAC  39  38  34.3  5.9  11.9   .492  ...
# 32     Benoit Benjamin      C   26  SEA  31  27  29.0  5.1  10.1   .502  ...
# 33     Winston Bennett     SF   25  CLE  27  13  12.4  1.5   4.0   .374  ...
# 34         Larry Bird*     SF   34  BOS  60  60  38.0  7.7  17.0   .454  ...
# 35    Rolando Blackman     SG   31  DAL  80  80  37.1  7.9  16.5   .482  ...
# 36        Lance Blanks     SG   24  DET  38   0   5.6  0.7   1.6   .426  ...
# 37     Mookie Blaylock     PG   23  NJN  72  70  35.9  6.0  14.4   .416  ...
# 38       Muggsy Bogues     PG   26  CHH  81  46  28.4  3.0   6.5   .460  ...
# 39          Manute Bol      C   28  PHI  82   6  18.6  0.8   2.0   .396  ...
# 40      Anthony Bonner     PF   22  SAC  34   6  22.1  3.0   6.8   .448  ...
# 41           Sam Bowie      C   29  NJN  62  51  30.9  5.1  11.7   .434  ...
# 42        Randy Breuer      C   30  MIN  73  44  20.6  2.7   6.0   .453  ...
# 43    Frank Brickowski     PF   31  MIL  75  73  25.5  5.0   9.4   .527  ...
# 44        Scott Brooks     PG   25  MIN  80   0  12.3  2.0   4.6   .430  ...
# 45        Chucky Brown     SF   22  CLE  74  51  20.1  3.6   6.8   .524  ...
# 46           Dee Brown     PG   22  BOS  82   5  23.7  3.5   7.5   .464  ...
# 47              Player    Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...
# 48          Mike Brown      C   27  UTA  82   2  17.0  1.6   3.5   .454  ...
# 49          Tony Brown  SG-SF   30  TOT  30   0   9.8  1.0   2.7   .375  ...
#
#     DRB   TRB   AST  STL  BLK  TOV   PF   PTS  Year             Players
# 0   1.4   2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991      Alaa Abdelnaby
# 1   1.3   1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991  Mahmoud Abdul-Rauf
# 2   3.2   5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991          Mark Acres
# 3   3.0   3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991       Michael Adams
# 4   3.1   4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991        Mark Aguirre
# 5   2.0   2.6   3.6  0.8  0.2  1.3  2.4  11.1  1991         Danny Ainge
# 6   1.8   2.8   1.1  0.4  0.2  1.0  2.1   5.8  1991         Mark Alarie
# 7   0.4   0.7   0.6  0.2  0.0  0.5  0.3   4.4  1991        Steve Alford
# 8   3.3   4.7   0.2  0.5  0.7  1.2  2.1   4.3  1991       Greg Anderson
# 9   1.9   2.9   0.1  0.3  0.3  0.8  1.1   2.7  1991       Greg Anderson
# 10  2.0   6.0   1.0  2.0  0.0  1.0  4.0   8.0  1991       Greg Anderson
# 11  4.1   5.8   0.3  0.6  0.9  1.5  2.6   5.2  1991       Greg Anderson
# 12  4.2   5.5   1.5  1.1  0.6  1.6  2.1  14.1  1991       Nick Anderson
# 13  3.2   4.5   1.4  0.8  0.2  1.2  2.0  14.6  1991        Ron Anderson
# 14  3.8   4.7   4.8  1.1  0.6  2.2  3.0  14.4  1991     Willie Anderson
# 15  2.0   3.8   0.4  0.4  0.1  0.5  1.9   5.7  1991      Michael Ansley
# 16  1.5   1.8   3.7  0.9  0.0  1.3  1.4   8.8  1991      B.J. Armstrong
# 17  0.6   1.6   1.9  0.3  0.0  0.9  3.0   4.7  1991       Vincent Askew
# 18  1.0   1.7   0.5  0.4  0.3  0.3  1.2   2.2  1991        Keith Askins
# 19  0.3   0.8   0.3  0.1  0.1  0.4  0.6   1.6  1991         Miloš Babić
# 20  3.7   5.0   1.5  0.6  1.1  1.6  2.0  12.4  1991        Thurl Bailey
# 21  0.9   1.6   0.0  0.0  0.3  0.3  0.7   1.1  1991         Cedric Ball
# 22  1.3   2.0   0.2  0.1  0.1  0.5  1.6   2.4  1991       Ken Bannister
# 23  6.3  10.1   4.2  1.6  0.5  3.1  2.6  27.6  1991     Charles Barkley
# 24  0.8   1.1   1.7  0.3  0.0  0.8  0.6   6.3  1991         Dana Barros
# 25  1.6   2.0   2.7  0.6  0.1  1.4  1.8  13.6  1991         John Battle
# 26  1.7   3.1   1.1  1.1  0.3  0.9  1.9   6.1  1991        Kenny Battle
# 27  2.0   3.3   0.9  1.2  0.4  1.1  1.6   6.0  1991        Kenny Battle
# 28  1.5   3.1   1.2  1.0  0.3  0.9  2.1   6.1  1991        Kenny Battle
# 29  1.3   2.2   0.5  0.0  0.6  0.5  1.3   4.5  1991     William Bedford
# 30  8.1  10.3   1.7  0.8  2.1  3.4  2.6  14.0  1991     Benoit Benjamin
# 31  9.6  12.0   1.9  0.7  2.3  3.5  2.8  14.9  1991     Benoit Benjamin
# 32  6.2   8.2   1.5  0.9  1.7  3.1  2.4  12.9  1991     Benoit Benjamin
# 33  1.3   2.4   1.0  0.3  0.1  0.7  1.9   4.3  1991     Winston Bennett
# 34  7.6   8.5   7.2  1.8  1.0  3.1  2.0  19.4  1991          Larry Bird
# 35  2.4   3.2   3.8  0.9  0.2  2.0  1.9  19.9  1991    Rolando Blackman
# 36  0.4   0.5   0.7  0.2  0.1  0.5  0.9   1.7  1991        Lance Blanks
# 37  2.5   3.5   6.1  2.3  0.6  2.9  2.5  14.1  1991     Mookie Blaylock
# 38  2.0   2.7   8.3  1.7  0.0  1.5  2.0   7.0  1991       Muggsy Bogues
# 39  3.5   4.3   0.2  0.2  3.0  0.8  2.2   1.9  1991          Manute Bol
# 40  3.0   4.7   1.4  1.1  0.1  1.2  1.8   7.4  1991      Anthony Bonner
# 41  4.9   7.7   2.4  0.7  1.5  2.3  2.8  12.9  1991           Sam Bowie
# 42  3.2   4.7   1.0  0.5  1.1  0.9  1.8   5.9  1991        Randy Breuer
# 43  4.0   5.7   1.7  1.1  0.6  2.1  3.4  12.6  1991    Frank Brickowski
# 44  0.6   0.9   2.6  0.7  0.1  0.6  1.5   5.3  1991        Scott Brooks
# 45  1.8   2.9   1.1  0.4  0.3  1.3  1.8   8.5  1991        Chucky Brown
# 46  1.7   2.2   4.2  1.0  0.2  1.7  2.0   8.7  1991           Dee Brown
# 47  DRB   TRB   AST  STL  BLK  TOV   PF   PTS  1991              Player
# 48  2.8   4.1   0.6  0.4  0.3  1.0  2.0   4.8  1991          Mike Brown
# 49  0.6   1.4   0.5  0.1  0.0  0.5  1.6   2.8  1991          Tony Brown
#
# [50 rows x 31 columns]

# %%
players["Player"].head(50)
# Out:
# 0         Alaa Abdelnaby
# 1     Mahmoud Abdul-Rauf
# 2             Mark Acres
# 3          Michael Adams
# 4           Mark Aguirre
# 5            Danny Ainge
# 6            Mark Alarie
# 7           Steve Alford
# 8          Greg Anderson
# 9          Greg Anderson
# 10         Greg Anderson
# 11         Greg Anderson
# 12         Nick Anderson
# 13          Ron Anderson
# 14       Willie Anderson
# 15        Michael Ansley
# 16        B.J. Armstrong
# 17         Vincent Askew
# 18          Keith Askins
# 19           Miloš Babić
# 20          Thurl Bailey
# 21           Cedric Ball
# 22         Ken Bannister
# 23       Charles Barkley
# 24           Dana Barros
# 25           John Battle
# 26          Kenny Battle
# 27          Kenny Battle
# 28          Kenny Battle
# 29       William Bedford
# 30       Benoit Benjamin
# 31       Benoit Benjamin
# 32       Benoit Benjamin
# 33       Winston Bennett
# 34            Larry Bird
# 35      Rolando Blackman
# 36          Lance Blanks
# 37       Mookie Blaylock
# 38         Muggsy Bogues
# 39            Manute Bol
# 40        Anthony Bonner
# 41             Sam Bowie
# 42          Randy Breuer
# 43      Frank Brickowski
# 44          Scott Brooks
# 45          Chucky Brown
# 46             Dee Brown
# 47                Player
# 48            Mike Brown
# 49            Tony Brown
# Name: Player, dtype: object

# %%
players.groupby(["Player", "Year"]).get_group(("Greg Anderson", 1991))
# Out:
#            Player Pos Age   Tm   G GS    MP   FG  FGA    FG%  ...  DRB  TRB  \
# 8   Greg Anderson  PF  26  TOT  68  2  13.6  1.7  4.0   .430  ...  3.3  4.7
# 9   Greg Anderson  PF  26  MIL  26  0   9.5  1.0  2.8   .370  ...  1.9  2.9
# 10  Greg Anderson  PF  26  NJN   1  0  18.0  4.0  4.0  1.000  ...  2.0  6.0
# 11  Greg Anderson  PF  26  DEN  41  2  16.1  2.1  4.7   .440  ...  4.1  5.8
#
#     AST  STL  BLK  TOV   PF  PTS  Year        Players
# 8   0.2  0.5  0.7  1.2  2.1  4.3  1991  Greg Anderson
# 9   0.1  0.3  0.3  0.8  1.1  2.7  1991  Greg Anderson
# 10  1.0  2.0  0.0  1.0  4.0  8.0  1991  Greg Anderson
# 11  0.3  0.6  0.9  1.5  2.6  5.2  1991  Greg Anderson
#
# [4 rows x 31 columns]

# %%
def single_row(df):
    if df.shape[0]==1:
        return df
    else:
        row = df[df["Tm"] == "TOT"]
        row["Tm"] = df.iloc[-1,:]["Tm"]
        return row
    
players = players.groupby(["Player", "Year"]).apply(single_row)

# %%
players.head(20)
# Out:
#                                  Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# Player        Year
# A.C. Green    1991 164       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6
#               1992 633       A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8
#               1993 1092      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6
#               1994 1579      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3
#               1995 2067      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5
#               1996 2563      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4
#               1997 3138      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8
#               1998 3725      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5
#               1999 4283      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1
#               2000 4811      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7
#               2001 5330      A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0
# A.J. Bramlett 2000 4684   A.J. Bramlett   C  23  CLE   8   0   7.6  0.5   2.6
# A.J. English  1991 127     A.J. English  SG  23  WSB  70  12  20.6  3.6   8.2
#               1992 597     A.J. English  SG  24  WSB  81   6  20.6  4.5  10.4
# A.J. Guyton   2001 5333     A.J. Guyton  PG  22  CHI  33   8  19.1  2.4   5.8
#               2002 5886     A.J. Guyton  PG  23  CHI  45   6  13.5  2.0   5.4
#               2003 6393     A.J. Guyton  PG  24  GSW   2   0   4.5  0.0   2.0
# A.J. Hammons  2017 14814   A.J. Hammons   C  24  DAL  22   0   7.4  0.8   1.9
# A.J. Price    2010 10727     A.J. Price  PG  23  IND  56   2  15.4  2.6   6.3
#               2011 11356     A.J. Price  PG  24  IND  50   0  15.9  2.3   6.4
#
#                            FG%  ...  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  \
# Player        Year              ...
# A.C. Green    1991 164    .476  ...  3.8  6.3  0.9  0.7  0.3  1.2  1.4   9.1
#               1992 633    .476  ...  5.6  9.3  1.4  1.1  0.4  1.4  1.7  13.6
#               1993 1092   .537  ...  5.2  8.7  1.4  1.1  0.5  1.4  1.8  12.8
#               1994 1579   .502  ...  5.8  9.2  1.7  0.9  0.5  1.2  1.7  14.7
#               1995 2067   .504  ...  5.8  8.2  1.5  0.7  0.4  1.4  1.8  11.2
#               1996 2563   .484  ...  4.7  6.8  0.9  0.5  0.3  1.0  1.7   7.5
#               1997 3138   .483  ...  5.2  7.9  0.8  0.8  0.2  0.9  1.7   7.2
#               1998 3725   .453  ...  5.5  8.1  1.5  1.0  0.3  0.8  1.9   7.3
#               1999 4283   .422  ...  2.9  4.6  0.5  0.6  0.2  0.4  1.4   4.9
#               2000 4811   .447  ...  4.0  5.9  1.0  0.6  0.2  0.6  1.5   5.0
#               2001 5330   .444  ...  2.5  3.8  0.5  0.4  0.1  0.5  1.5   4.5
# A.J. Bramlett 2000 4684   .190  ...  1.3  2.8  0.0  0.1  0.0  0.4  1.6   1.0
# A.J. English  1991 127    .439  ...  1.2  2.1  2.5  0.4  0.2  1.6  1.8   8.8
#               1992 597    .433  ...  1.2  2.1  1.8  0.4  0.1  1.1  2.0  10.9
# A.J. Guyton   2001 5333   .406  ...  0.8  1.1  1.9  0.3  0.2  0.7  1.1   6.0
#               2002 5886   .361  ...  0.7  1.0  1.8  0.2  0.2  0.8  0.5   5.4
#               2003 6393   .000  ...  0.0  0.0  1.0  0.5  0.0  0.5  0.0   0.0
# A.J. Hammons  2017 14814  .405  ...  1.3  1.6  0.2  0.0  0.6  0.5  1.0   2.2
# A.J. Price    2010 10727  .410  ...  1.4  1.6  1.9  0.6  0.1  1.1  0.9   7.3
#               2011 11356  .356  ...  1.1  1.4  2.2  0.6  0.0  1.1  1.2   6.5
#
#                           Year        Players
# Player        Year
# A.C. Green    1991 164    1991     A.C. Green
#               1992 633    1992     A.C. Green
#               1993 1092   1993     A.C. Green
#               1994 1579   1994     A.C. Green
#               1995 2067   1995     A.C. Green
#               1996 2563   1996     A.C. Green
#               1997 3138   1997     A.C. Green
#               1998 3725   1998     A.C. Green
#               1999 4283   1999     A.C. Green
#               2000 4811   2000     A.C. Green
#               2001 5330   2001     A.C. Green
# A.J. Bramlett 2000 4684   2000  A.J. Bramlett
# A.J. English  1991 127    1991   A.J. English
#               1992 597    1992   A.J. English
# A.J. Guyton   2001 5333   2001    A.J. Guyton
#               2002 5886   2002    A.J. Guyton
#               2003 6393   2003    A.J. Guyton
# A.J. Hammons  2017 14814  2017   A.J. Hammons
# A.J. Price    2010 10727  2010     A.J. Price
#               2011 11356  2011     A.J. Price
#
# [20 rows x 31 columns]

# %%
players.index = players.index.droplevel()

# %%
players.index = players.index.droplevel()

# %%
players.head(20)
# Out:
#               Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  DRB  \
# 164       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  3.8
# 633       A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  5.6
# 1092      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  5.2
# 1579      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  5.8
# 2067      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  5.8
# 2563      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4  .484  ...  4.7
# 3138      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8  .483  ...  5.2
# 3725      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5  .453  ...  5.5
# 4283      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1  .422  ...  2.9
# 4811      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7  .447  ...  4.0
# 5330      A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0  .444  ...  2.5
# 4684   A.J. Bramlett   C  23  CLE   8   0   7.6  0.5   2.6  .190  ...  1.3
# 127     A.J. English  SG  23  WSB  70  12  20.6  3.6   8.2  .439  ...  1.2
# 597     A.J. English  SG  24  WSB  81   6  20.6  4.5  10.4  .433  ...  1.2
# 5333     A.J. Guyton  PG  22  CHI  33   8  19.1  2.4   5.8  .406  ...  0.8
# 5886     A.J. Guyton  PG  23  CHI  45   6  13.5  2.0   5.4  .361  ...  0.7
# 6393     A.J. Guyton  PG  24  GSW   2   0   4.5  0.0   2.0  .000  ...  0.0
# 14814   A.J. Hammons   C  24  DAL  22   0   7.4  0.8   1.9  .405  ...  1.3
# 10727     A.J. Price  PG  23  IND  56   2  15.4  2.6   6.3  .410  ...  1.4
# 11356     A.J. Price  PG  24  IND  50   0  15.9  2.3   6.4  .356  ...  1.1
#
#        TRB  AST  STL  BLK  TOV   PF   PTS  Year        Players
# 164    6.3  0.9  0.7  0.3  1.2  1.4   9.1  1991     A.C. Green
# 633    9.3  1.4  1.1  0.4  1.4  1.7  13.6  1992     A.C. Green
# 1092   8.7  1.4  1.1  0.5  1.4  1.8  12.8  1993     A.C. Green
# 1579   9.2  1.7  0.9  0.5  1.2  1.7  14.7  1994     A.C. Green
# 2067   8.2  1.5  0.7  0.4  1.4  1.8  11.2  1995     A.C. Green
# 2563   6.8  0.9  0.5  0.3  1.0  1.7   7.5  1996     A.C. Green
# 3138   7.9  0.8  0.8  0.2  0.9  1.7   7.2  1997     A.C. Green
# 3725   8.1  1.5  1.0  0.3  0.8  1.9   7.3  1998     A.C. Green
# 4283   4.6  0.5  0.6  0.2  0.4  1.4   4.9  1999     A.C. Green
# 4811   5.9  1.0  0.6  0.2  0.6  1.5   5.0  2000     A.C. Green
# 5330   3.8  0.5  0.4  0.1  0.5  1.5   4.5  2001     A.C. Green
# 4684   2.8  0.0  0.1  0.0  0.4  1.6   1.0  2000  A.J. Bramlett
# 127    2.1  2.5  0.4  0.2  1.6  1.8   8.8  1991   A.J. English
# 597    2.1  1.8  0.4  0.1  1.1  2.0  10.9  1992   A.J. English
# 5333   1.1  1.9  0.3  0.2  0.7  1.1   6.0  2001    A.J. Guyton
# 5886   1.0  1.8  0.2  0.2  0.8  0.5   5.4  2002    A.J. Guyton
# 6393   0.0  1.0  0.5  0.0  0.5  0.0   0.0  2003    A.J. Guyton
# 14814  1.6  0.2  0.0  0.6  0.5  1.0   2.2  2017   A.J. Hammons
# 10727  1.6  1.9  0.6  0.1  1.1  0.9   7.3  2010     A.J. Price
# 11356  1.4  2.2  0.6  0.0  1.1  1.2   6.5  2011     A.J. Price
#
# [20 rows x 31 columns]

# %%
players[players["Player"] == "Greg Anderson"]
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  DRB  \
# 8     Greg Anderson  PF  26  DEN  68   2  13.6  1.7   4.0  .430  ...  3.3
# 467   Greg Anderson  PF  27  DEN  82  82  34.1  4.7  10.4  .456  ...  7.4
# 1412  Greg Anderson  PF  29  DET  77  47  21.1  2.6   4.8  .543  ...  5.0
# 1911  Greg Anderson  PF  30  ATL  51   0  12.2  1.1   2.0  .548  ...  2.5
# 2381  Greg Anderson  PF  31  SAS  46   7   7.5  0.5   1.0  .511  ...  1.5
# 2948  Greg Anderson   C  32  SAS  82  48  20.2  1.6   3.2  .496  ...  3.5
# 3541  Greg Anderson   C  33  ATL  50   0   8.0  0.7   1.6  .444  ...  1.6
#
#        TRB  AST  STL  BLK  TOV   PF   PTS  Year        Players
# 8      4.7  0.2  0.5  0.7  1.2  2.1   4.3  1991  Greg Anderson
# 467   11.5  1.0  1.1  0.8  2.5  3.2  11.5  1992  Greg Anderson
# 1412   7.4  0.7  0.7  0.9  1.2  3.0   6.4  1994  Greg Anderson
# 1911   3.7  0.3  0.5  0.6  0.6  2.0   2.9  1995  Greg Anderson
# 2381   2.2  0.2  0.2  0.5  0.5  1.4   1.2  1996  Greg Anderson
# 2948   5.5  0.4  0.8  0.8  0.9  2.7   3.9  1997  Greg Anderson
# 3541   2.4  0.3  0.4  0.2  0.3  1.7   1.8  1998  Greg Anderson
#
# [7 rows x 31 columns]

# %%
combined = players.merge(mvps, how="outer", on=["Player", "Year"])

# %%
combined.head(5)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  BLK  TOV  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7  0.3  1.2
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1  0.4  1.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1  0.5  1.4
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9  0.5  1.2
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  0.7  0.4  1.4
#
#     PF   PTS  Year     Players Pts Won Pts Max Share
# 0  1.4   9.1  1991  A.C. Green     NaN     NaN   NaN
# 1  1.7  13.6  1992  A.C. Green     NaN     NaN   NaN
# 2  1.8  12.8  1993  A.C. Green     NaN     NaN   NaN
# 3  1.7  14.7  1994  A.C. Green     NaN     NaN   NaN
# 4  1.8  11.2  1995  A.C. Green     NaN     NaN   NaN
#
# [5 rows x 34 columns]

# %%
combined[combined["Pts Won"] > 0]
# Out:
#               Player    Pos Age   Tm   G  GS    MP    FG   FGA   FG%  ...  \
# 197     Al Jefferson      C  29  CHA  73  73  35.0   9.6  18.8  .509  ...
# 346    Allen Iverson     PG  21  PHI  76  74  40.1   8.2  19.8  .416  ...
# 348    Allen Iverson     SG  23  PHI  48  48  41.5   9.1  22.0  .412  ...
# 349    Allen Iverson     SG  24  PHI  70  70  40.8  10.4  24.8  .421  ...
# 350    Allen Iverson     SG  25  PHI  71  71  42.0  10.7  25.5  .420  ...
# ...              ...    ...  ..  ...  ..  ..   ...   ...   ...   ...  ...
# 14170   Vince Carter     SF  23  TOR  82  82  38.1   9.6  20.7  .465  ...
# 14171   Vince Carter     SF  24  TOR  75  75  39.7  10.2  22.1  .460  ...
# 14175   Vince Carter  SF-SG  28  NJN  77  76  36.7   9.0  20.0  .452  ...
# 14549       Yao Ming      C  23  HOU  82  82  32.8   6.5  12.5  .522  ...
# 14554       Yao Ming      C  28  HOU  77  77  33.6   7.4  13.4  .548  ...
#
#        STL  BLK  TOV   PF   PTS  Year        Players Pts Won Pts Max  Share
# 197    0.9  1.1  1.7  2.4  21.8  2014   Al Jefferson    34.0  1250.0  0.027
# 346    2.1  0.3  4.4  3.1  23.5  1997  Allen Iverson     1.0  1150.0  0.001
# 348    2.3  0.1  3.5  2.0  26.8  1999  Allen Iverson   319.0  1180.0  0.270
# 349    2.1  0.1  3.3  2.3  28.4  2000  Allen Iverson   132.0  1210.0  0.109
# 350    2.5  0.3  3.3  2.1  31.1  2001  Allen Iverson  1121.0  1240.0  0.904
# ...    ...  ...  ...  ...   ...   ...            ...     ...     ...    ...
# 14170  1.3  1.1  2.2  3.2  25.7  2000   Vince Carter    51.0  1210.0  0.042
# 14171  1.5  1.1  2.2  2.7  27.6  2001   Vince Carter     7.0  1240.0  0.006
# 14175  1.4  0.6  2.2  3.2  24.5  2005   Vince Carter     3.0  1270.0  0.002
# 14549  0.3  1.9  2.5  3.3  17.5  2004       Yao Ming     1.0  1230.0  0.001
# 14554  0.4  1.9  3.0  3.3  19.7  2009       Yao Ming     1.0  1210.0  0.001
#
# [486 rows x 34 columns]

# %%
combined[["Pts Won", 'Pts Max', "Share"]].fillna(0, inplace=True)
# Out:
# /var/folders/36/x9hhmrvj3970d5_k7qbbwcyw0000gn/T/ipykernel_41497/3490916651.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined[["Pts Won", 'Pts Max', "Share"]].fillna(0, inplace=True)

# %%
combined.head(5)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  BLK  TOV  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7  0.3  1.2
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1  0.4  1.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1  0.5  1.4
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9  0.5  1.2
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  0.7  0.4  1.4
#
#     PF   PTS  Year     Players Pts Won Pts Max Share
# 0  1.4   9.1  1991  A.C. Green     NaN     NaN   NaN
# 1  1.7  13.6  1992  A.C. Green     NaN     NaN   NaN
# 2  1.8  12.8  1993  A.C. Green     NaN     NaN   NaN
# 3  1.7  14.7  1994  A.C. Green     NaN     NaN   NaN
# 4  1.8  11.2  1995  A.C. Green     NaN     NaN   NaN
#
# [5 rows x 34 columns]

# %%
combined[["Pts Won", 'Pts Max', "Share"]] = combined[["Pts Won", 'Pts Max', "Share"]].fillna(0)

# %%
combined.head(5)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  BLK  TOV  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7  0.3  1.2
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1  0.4  1.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1  0.5  1.4
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9  0.5  1.2
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  0.7  0.4  1.4
#
#     PF   PTS  Year     Players Pts Won Pts Max Share
# 0  1.4   9.1  1991  A.C. Green     0.0     0.0   0.0
# 1  1.7  13.6  1992  A.C. Green     0.0     0.0   0.0
# 2  1.8  12.8  1993  A.C. Green     0.0     0.0   0.0
# 3  1.7  14.7  1994  A.C. Green     0.0     0.0   0.0
# 4  1.8  11.2  1995  A.C. Green     0.0     0.0   0.0
#
# [5 rows x 34 columns]

# %%
teams = pd.read_csv("teams.csv")

# %%
teams = teams[~teams["W"].str.contains("Division")]

# %%
teams["Team"] = teams["Team"].str.replace("*","", regex=False)

# %%
teams.head(5)
# Out:
#    Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0           0  56  26  .683     —  111.5  105.7   5.22  1991
# 1           1  44  38  .537  12.0  105.4  105.6  -0.39  1991
# 2           2  39  43  .476  17.0  103.1  103.3  -0.43  1991
# 3           3  30  52  .366  26.0  101.4  106.4  -4.84  1991
# 4           4  26  56  .317  30.0  102.9  107.5  -4.53  1991
#
#                  Team
# 0      Boston Celtics
# 1  Philadelphia 76ers
# 2     New York Knicks
# 3  Washington Bullets
# 4     New Jersey Nets

# %%
teams["Team"].unique()
# Out:
# array(['Boston Celtics', 'Philadelphia 76ers', 'New York Knicks',
#        'Washington Bullets', 'New Jersey Nets', 'Miami Heat',
#        'Chicago Bulls', 'Detroit Pistons', 'Milwaukee Bucks',
#        'Atlanta Hawks', 'Indiana Pacers', 'Cleveland Cavaliers',
#        'Charlotte Hornets', 'San Antonio Spurs', 'Utah Jazz',
#        'Houston Rockets', 'Orlando Magic', 'Minnesota Timberwolves',
#        'Dallas Mavericks', 'Denver Nuggets', 'Portland Trail Blazers',
#        'Los Angeles Lakers', 'Phoenix Suns', 'Golden State Warriors',
#        'Seattle SuperSonics', 'Los Angeles Clippers', 'Sacramento Kings',
#        'Toronto Raptors', 'Vancouver Grizzlies', 'Washington Wizards',
#        'Memphis Grizzlies', 'New Orleans Hornets', 'Charlotte Bobcats',
#        'New Orleans/Oklahoma City Hornets', 'Oklahoma City Thunder',
#        'Brooklyn Nets', 'New Orleans Pelicans'], dtype=object)

# %%
combined["Tm"].unique()
# Out:
# array(['LAL', 'PHO', 'DAL', 'MIA', 'CLE', 'WSB', 'CHI', 'GSW', 'IND',
#        'WAS', 'MIN', 'BOS', 'HOU', 'DEN', 'ORL', 'NOH', 'TOR', 'SAC',
#        'CHO', 'PHI', 'POR', 'DET', 'OKC', 'UTA', 'MIL', 'VAN', 'SEA',
#        'NJN', 'NOK', 'LAC', 'ATL', 'CHA', 'MEM', 'NYK', 'NOP', 'BRK',
#        'SAS', 'CHH'], dtype=object)

# %%
nicknames = {}

with open("nicknames.csv") as f:
    lines = f.readlines()
    for line in lines[1:]:
        abbrev,name = line.replace("\n", "").split(",")
        nicknames[abbrev] = name

# %%
nicknames
# Out:
# {'ATL': 'Atlanta Hawks',
#  'BRK': 'Brooklyn Nets',
#  'BKN': 'Brooklyn Nets',
#  'BOS': 'Boston Celtics',
#  'CHA': 'Charlotte Bobcats',
#  'CHH': 'Charlotte Hornets',
#  'CHO': 'Charlotte Hornets',
#  'CHI': 'Chicago Bulls',
#  'CLE': 'Cleveland Cavaliers',
#  'DAL': 'Dallas Mavericks',
#  'DEN': 'Denver Nuggets',
#  'DET': 'Detroit Pistons',
#  'GSW': 'Golden State Warriors',
#  'HOU': 'Houston Rockets',
#  'IND': 'Indiana Pacers',
#  'LAC': 'Los Angeles Clippers',
#  'LAL': 'Los Angeles Lakers',
#  'MEM': 'Memphis Grizzlies',
#  'MIA': 'Miami Heat',
#  'MIL': 'Milwaukee Bucks',
#  'MIN': 'Minnesota Timberwolves',
#  'NJN': 'New Jersey Nets',
#  'NOH': 'New Orleans Hornets',
#  'NOP': 'New Orleans Pelicans',
#  'NOK': 'New Orleans/Oklahoma City Hornets',
#  'NYK': 'New York Knicks',
#  'OKC': 'Oklahoma City Thunder',
#  'ORL': 'Orlando Magic',
#  'PHI': 'Philadelphia 76ers',
#  'PHX': 'Phoenix Suns',
#  'PHO': 'Phoenix Suns',
#  'POR': 'Portland Trail Blazers',
#  'SEA': 'Seattle SuperSonics',
#  'SAC': 'Sacramento Kings',
#  'SAS': 'San Antonio Spurs',
#  'TOR': 'Toronto Raptors',
#  'UTA': 'Utah Jazz',
#  'WAS': 'Washington Bullets'}

# %%
combined["Team"] = combined["Tm"].map(nicknames)

# %%
combined.head(5)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  BLK  TOV   PF  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.3  1.2  1.4
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  0.4  1.4  1.7
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  0.5  1.4  1.8
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.5  1.2  1.7
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  0.4  1.4  1.8
#
#     PTS  Year     Players Pts Won Pts Max Share                Team
# 0   9.1  1991  A.C. Green     0.0     0.0   0.0  Los Angeles Lakers
# 1  13.6  1992  A.C. Green     0.0     0.0   0.0  Los Angeles Lakers
# 2  12.8  1993  A.C. Green     0.0     0.0   0.0  Los Angeles Lakers
# 3  14.7  1994  A.C. Green     0.0     0.0   0.0        Phoenix Suns
# 4  11.2  1995  A.C. Green     0.0     0.0   0.0        Phoenix Suns
#
# [5 rows x 35 columns]

# %%
stats = combined.merge(teams, how="outer", on=["Team", "Year"])

# %%
stats
# Out:
#                Player  Pos  Age   Tm    G   GS    MP   FG   FGA   FG%  ...  \
# 0          A.C. Green   PF   27  LAL   82   21  26.4  3.1   6.6  .476  ...
# 1         Byron Scott   SG   29  LAL   82   82  32.1  6.1  12.8  .477  ...
# 2      Elden Campbell   PF   22  LAL   52    0   7.3  1.1   2.4  .455  ...
# 3       Irving Thomas   PF   25  LAL   26    0   4.2  0.7   1.9  .340  ...
# 4        James Worthy   SF   29  LAL   78   74  38.6  9.2  18.7  .492  ...
# ...               ...  ...  ...  ...  ...  ...   ...  ...   ...   ...  ...
# 14730             NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN  ...
# 14731             NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN  ...
# 14732             NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN  ...
# 14733             NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN  ...
# 14734             NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN  ...
#
#       Share                Team Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G  \
# 0       0.0  Los Angeles Lakers       10.0  58  24  .707   5.0  106.3   99.6
# 1       0.0  Los Angeles Lakers       10.0  58  24  .707   5.0  106.3   99.6
# 2       0.0  Los Angeles Lakers       10.0  58  24  .707   5.0  106.3   99.6
# 3       0.0  Los Angeles Lakers       10.0  58  24  .707   5.0  106.3   99.6
# 4       0.0  Los Angeles Lakers       10.0  58  24  .707   5.0  106.3   99.6
# ...     ...                 ...        ...  ..  ..   ...   ...    ...    ...
# 14730   NaN  Washington Wizards       13.0  43  39  .524   1.0  106.6  106.0
# 14731   NaN  Washington Wizards       15.0  32  50  .390  10.0  114.0  116.9
# 14732   NaN  Washington Wizards       15.0  25  47  .347  18.5  114.4  119.1
# 14733   NaN  Washington Wizards       14.0  34  38  .472   7.0  116.6  118.5
# 14734   NaN  Washington Wizards       15.0  35  47  .427  18.0  108.6  112.0
#
#          SRS
# 0       6.73
# 1       6.73
# 2       6.73
# 3       6.73
# 4       6.73
# ...      ...
# 14730   0.53
# 14731  -3.30
# 14732  -5.24
# 14733  -1.85
# 14734  -3.23
#
# [14735 rows x 43 columns]

# %%
del stats["Unnamed: 0"]

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age        float64
# Tm          object
# G          float64
# GS         float64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Players     object
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W          float64
# L          float64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats = stats.apply(pd.to_numeric, errors="ignore")

# %%
stats["GB"].unique()
# Out:
# array([ 5. , 14. , 23. ,  7. ,  0. , 40. , 42. , 18. ,  6. , 24. ,  nan,
#        37. , 29. , 21. , 28. , 25. ,  8. , 19. ,  1. , 13. , 17. ,  3. ,
#        15. ,  9. ,  2. , 35. , 20. , 11. , 26. , 16. , 41. , 12. , 10. ,
#        30. , 34. ,  4. ,  1.5, 22. , 51. , 36. , 43. , 39. , 31. , 48. ,
#        46. , 10.5, 32. , 38. , 27. , 33. , 50. , 21.5, 45. , 22.5, 25.5,
#         3.5, 20.5, 11.5, 52. , 56. ,  2.5, 12.5, 44. , 47. , 32.5,  4.5,
#        18.5])

# %%
stats["GB"] = stats["GB"].str.replace("—", "0")

# %%
stats["Age"].unique()
# Out:
# array([27., 29., 22., 25., 32., 31., 36., 30., 28., 23., 33., 24., 37.,
#        34., 35., 26., 21., 20., 18., 38., 19., 41., 42., 39., 40., 44.,
#        43., nan])

# %%
stats["Age"] = stats["Age"].replace(".","", regex=False)

# %%
stats.to_csv("player_mvp_stats.csv")

# %%
highest_scoring = stats[stats["G"] > 70].sort_values("PTS", ascending=False).head(10)

# %%
highest_scoring.plot.bar("Player", "PTS")
# Out:
# <Axes: xlabel='Player'>

# %%
highest_scoring_per = stats.groupby("Year").apply(lambda x: x.sort_values("PTS", ascending=False).head(1))

# %%
highest_scoring_per.plot.bar("Year", "PTS")
# Out:
# <Axes: xlabel='Year'>

# %%
stats.corr()["Share"]
# Out:
# /var/folders/36/x9hhmrvj3970d5_k7qbbwcyw0000gn/T/ipykernel_41497/2927041331.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   stats.corr()["Share"]
# Age        0.018420
# G          0.089176
# GS         0.167169
# MP         0.160854
# FG         0.275277
# FGA        0.247570
# FG%        0.065081
# 3P         0.093106
# 3PA        0.093229
# 3P%        0.013697
# 2P         0.276305
# 2PA        0.251837
# 2P%        0.060965
# eFG%       0.057892
# FT         0.317906
# FTA        0.323022
# FT%        0.037299
# ORB        0.102755
# DRB        0.216642
# TRB        0.189423
# AST        0.199825
# STL        0.173410
# BLK        0.154909
# TOV        0.233015
# PF         0.072800
# PTS        0.287185
# Year      -0.009141
# Pts Won    0.994986
# Pts Max    0.522075
# Share      1.000000
# W          0.121004
# L         -0.120228
# W/L%       0.124764
# GB        -0.100622
# PS/G       0.042095
# PA/G      -0.038812
# SRS        0.119793
# Name: Share, dtype: float64

# %%
stats.corr()["Share"].plot.bar()
# Out:
# /var/folders/36/x9hhmrvj3970d5_k7qbbwcyw0000gn/T/ipykernel_41497/197462118.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   stats.corr()["Share"].plot.bar()
# <Axes: >
