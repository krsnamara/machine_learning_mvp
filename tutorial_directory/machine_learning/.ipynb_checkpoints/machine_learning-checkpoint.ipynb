# %%
import pandas as pd

# %%
stats = pd.read_csv("player_mvp_stats.csv")

# %%
stats.head(50)
# Out:
#              Player Pos   Age   Tm     G    GS    MP   FG   FGA    FG%  ...  \
# 0        A.C. Green  PF  27.0  LAL  82.0  21.0  26.4  3.1   6.6  0.476  ...
# 1       Byron Scott  SG  29.0  LAL  82.0  82.0  32.1  6.1  12.8  0.477  ...
# 2    Elden Campbell  PF  22.0  LAL  52.0   0.0   7.3  1.1   2.4  0.455  ...
# 3     Irving Thomas  PF  25.0  LAL  26.0   0.0   4.2  0.7   1.9  0.340  ...
# 4      James Worthy  SF  29.0  LAL  78.0  74.0  38.6  9.2  18.7  0.492  ...
# 5        Larry Drew  PG  32.0  LAL  48.0   2.0  10.3  1.1   2.6  0.432  ...
# 6     Magic Johnson  PG  31.0  LAL  79.0  79.0  37.1  5.9  12.4  0.477  ...
# 7   Mychal Thompson   C  36.0  LAL  72.0   4.0  15.0  1.6   3.2  0.496  ...
# 8       Sam Perkins  PF  29.0  LAL  73.0  66.0  34.3  5.0  10.2  0.495  ...
# 9      Terry Teagle  SG  30.0  LAL  82.0   0.0  18.3  4.1   9.2  0.443  ...
# 10       Tony Smith  SG  22.0  LAL  64.0   1.0  10.9  1.5   3.4  0.441  ...
# 11      Vlade Divac   C  22.0  LAL  82.0  81.0  28.2  4.4   7.8  0.565  ...
# 12       A.C. Green  PF  28.0  LAL  82.0  53.0  35.4  4.7   9.8  0.476  ...
# 13      Byron Scott  SG  30.0  LAL  82.0  82.0  32.7  5.6  12.3  0.458  ...
# 14     Chucky Brown  SF  23.0  LAL  42.0   2.0  10.3  1.4   3.0  0.469  ...
# 15   Cliff Robinson  PF  31.0  LAL   9.0   0.0   8.7  1.2   3.0  0.407  ...
# 16  Demetrius Calip  PG  22.0  LAL   7.0   0.0   8.3  0.6   2.6  0.222  ...
# 17   Elden Campbell   C  23.0  LAL  81.0  47.0  23.2  2.7   6.1  0.448  ...
# 18       Jack Haley   C  28.0  LAL  49.0   9.0   8.0  0.6   1.7  0.369  ...
# 19     James Worthy  SF  30.0  LAL  54.0  54.0  39.0  8.3  18.6  0.447  ...
# 20      Keith Owens  SF  22.0  LAL  20.0   0.0   4.0  0.5   1.6  0.281  ...
# 21     Rory Sparrow  PG  33.0  LAL  46.0   0.0  10.6  1.3   3.3  0.384  ...
# 22      Sam Perkins  PF  30.0  LAL  63.0  63.0  37.0  5.7  12.7  0.450  ...
# 23   Sedale Threatt  PG  30.0  LAL  82.0  82.0  37.4  6.2  12.7  0.489  ...
# 24     Terry Teagle  SG  31.0  LAL  82.0   0.0  19.5  4.4   9.8  0.452  ...
# 25       Tony Smith  PG  23.0  LAL  63.0   0.0  13.0  1.8   4.5  0.399  ...
# 26      Vlade Divac   C  23.0  LAL  36.0  18.0  27.2  4.4   8.8  0.495  ...
# 27       A.C. Green  PF  29.0  LAL  82.0  55.0  34.4  4.6   8.6  0.537  ...
# 28   Alex Blackwell  SF  22.0  LAL  27.0   0.0   4.0  0.5   1.6  0.333  ...
# 29   Anthony Peeler  SG  23.0  LAL  77.0  11.0  21.5  3.9   8.2  0.468  ...
# 30  Benoit Benjamin   C  28.0  LAL  59.0   6.0  12.8  2.3   4.6  0.491  ...
# 31      Byron Scott  SG  31.0  LAL  58.0  53.0  28.9  5.1  11.4  0.449  ...
# 32    Doug Christie  SG  22.0  LAL  23.0   0.0  14.4  2.0   4.6  0.425  ...
# 33     Duane Cooper  PG  23.0  LAL  65.0   0.0   9.9  1.0   2.4  0.392  ...
# 34   Elden Campbell  PF  24.0  LAL  79.0  13.0  19.6  3.0   6.6  0.458  ...
# 35    James Edwards   C  37.0  LAL  52.0   0.0  11.9  2.3   5.2  0.452  ...
# 36     James Worthy  SF  31.0  LAL  82.0  69.0  28.8  6.2  13.9  0.447  ...
# 37   Sedale Threatt  PG  31.0  LAL  82.0  82.0  35.3  6.4  12.5  0.508  ...
# 38       Tony Smith  SG  24.0  LAL  55.0   9.0  13.7  2.4   5.0  0.484  ...
# 39      Vlade Divac   C  24.0  LAL  82.0  69.0  30.8  4.8  10.0  0.485  ...
# 40       A.C. Green  PF  30.0  PHO  82.0  55.0  34.5  5.7  11.3  0.502  ...
# 41  Cedric Ceballos  SF  24.0  PHO  53.0  43.0  30.2  8.0  15.0  0.535  ...
# 42  Charles Barkley  PF  30.0  PHO  65.0  65.0  35.4  8.0  16.1  0.495  ...
# 43      Dan Majerle  SG  28.0  PHO  80.0  76.0  40.1  6.0  14.2  0.418  ...
# 44      Danny Ainge  SG  34.0  PHO  68.0   1.0  22.9  3.3   7.9  0.417  ...
# 45     Duane Cooper  PG  24.0  PHO  23.0   2.0   5.9  0.8   1.8  0.439  ...
# 46     Elliot Perry  PG  24.0  PHO  27.0   9.0  16.0  1.6   4.2  0.372  ...
# 47    Frank Johnson  PG  35.0  PHO  70.0   5.0  12.5  1.9   4.3  0.448  ...
# 48    Jerrod Mustaf  PF  24.0  PHO  33.0   2.0   5.9  0.9   2.5  0.357  ...
# 49       Joe Kleine   C  32.0  PHO  74.0   4.0  11.5  1.7   3.5  0.488  ...
#
#     Pts Max  Share                Team     W     L   W/L%    GB   PS/G   PA/G  \
# 0       0.0  0.000  Los Angeles Lakers  58.0  24.0  0.707   5.0  106.3   99.6
# 1       0.0  0.000  Los Angeles Lakers  58.0  24.0  0.707   5.0  106.3   99.6
# 2       0.0  0.000  Los Angeles Lakers  58.0  24.0  0.707   5.0  106.3   99.6
# 3       0.0  0.000  Los Angeles Lakers  58.0  24.0  0.707   5.0  106.3   99.6
# 4       0.0  0.000  Los Angeles Lakers  58.0  24.0  0.707   5.0  106.3   99.6
# 5       0.0  0.000  Los Angeles Lakers  58.0  24.0  0.707   5.0  106.3   99.6
# 6     960.0  0.518  Los Angeles Lakers  58.0  24.0  0.707   5.0  106.3   99.6
# 7       0.0  0.000  Los Angeles Lakers  58.0  24.0  0.707   5.0  106.3   99.6
# 8       0.0  0.000  Los Angeles Lakers  58.0  24.0  0.707   5.0  106.3   99.6
# 9       0.0  0.000  Los Angeles Lakers  58.0  24.0  0.707   5.0  106.3   99.6
# 10      0.0  0.000  Los Angeles Lakers  58.0  24.0  0.707   5.0  106.3   99.6
# 11      0.0  0.000  Los Angeles Lakers  58.0  24.0  0.707   5.0  106.3   99.6
# 47      0.0  0.000        Phoenix Suns  56.0  26.0  0.683   7.0  108.2  103.4
# 48      0.0  0.000        Phoenix Suns  56.0  26.0  0.683   7.0  108.2  103.4
# 49      0.0  0.000        Phoenix Suns  56.0  26.0  0.683   7.0  108.2  103.4
#
#      SRS
# 0   6.73
# 1   6.73
# 2   6.73
# 3   6.73
# 4   6.73
# 5   6.73
# 6   6.73
# 7   6.73
# 8   6.73
# 9   6.73
# 10  6.73
# 11  6.73
# 12 -0.95
# 13 -0.95
# 14 -0.95
# 15 -0.95
# 16 -0.95
# 17 -0.95
# 18 -0.95
# 19 -0.95
# 20 -0.95
# 21 -0.95
# 22 -0.95
# 23 -0.95
# 24 -0.95
# 25 -0.95
# 26 -0.95
# 27 -1.20
# 28 -1.20
# 29 -1.20
# 30 -1.20
# 31 -1.20
# 32 -1.20
# 33 -1.20
# 34 -1.20
# 35 -1.20
# 36 -1.20
# 37 -1.20
# 38 -1.20
# 39 -1.20
# 40  4.68
# 41  4.68
# 42  4.68
# 43  4.68
# 44  4.68
# 45  4.68
# 46  4.68
# 47  4.68
# 48  4.68
# 49  4.68
#
# [50 rows x 41 columns]

# %%
del stats["Unnamed: 0"]

# %%
pd.isnull(stats).sum()
# Out:
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        0
# 3P         0
# 3PA        0
# 3P%        0
# 2P         0
# 2PA        0
# 2P%        0
# eFG%       0
# FT         0
# FTA        0
# FT%        0
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# Year       0
# Pts Won    0
# Pts Max    0
# Share      0
# Team       0
# W          0
# L          0
# W/L%       0
# GB         0
# PS/G       0
# PA/G       0
# SRS        0
# dtype: int64

# %%
stats[pd.isnull(stats["3P%"])]
# Out:
# Empty DataFrame
# Columns: [Player, Pos, Age, Tm, G, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS, Year, Pts Won, Pts Max, Share, Team, W, L, W/L%, GB, PS/G, PA/G, SRS]
# Index: []
#
# [0 rows x 41 columns]

# %%
stats[pd.isnull(stats["3P%"])][["Player", "3PA"]]
# Out:
# Empty DataFrame
# Columns: [Player, 3PA]
# Index: []

# %%
stats = stats.fillna(0)

# %%
stats = pd.read_csv("repo_player_mvp_stats.csv")

# %%
del stats["Unnamed: 0"]

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
predictors = ['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS']

# %%
train = stats[stats["Year"] < 2021]

# %%
test = stats[stats["Year"] == 2021]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
reg.fit(train[predictors], train["Share"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])
